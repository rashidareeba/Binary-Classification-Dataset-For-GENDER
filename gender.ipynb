# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("mw.csv")

# %%
df.head(104)
# Out:
#      GENDER  HEIGHT  HAND_LENGTH  FOOT_LENGTH
# 0         1  1760.2        208.6        269.6
# 1         1  1730.1        207.6        251.3
# 2         1  1659.6        173.2        193.6
# 3         1  1751.3        258.0        223.8
# 4         1  1780.6        212.3        282.1
# ..      ...     ...          ...          ...
# 99        2  1531.1        173.9        204.2
# 100       2  1669.5        199.7        246.6
# 101       2  1583.5        189.9        238.2
# 102       2  1634.1        195.0        240.5
# 103       2  1594.8        189.2        232.1
#
# [104 rows x 4 columns]

# %%
df.shape
# Out:
# (155, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GENDER       155 non-null    int64
#  1   HEIGHT       155 non-null    float64
#  2   HAND_LENGTH  155 non-null    float64
#  3   FOOT_LENGTH  155 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 5.0 KB

# %%
df.head()
# Out:
#    GENDER  HEIGHT  HAND_LENGTH  FOOT_LENGTH
# 0       1  1760.2        208.6        269.6
# 1       1  1730.1        207.6        251.3
# 2       1  1659.6        173.2        193.6
# 3       1  1751.3        258.0        223.8
# 4       1  1780.6        212.3        282.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GENDER       155 non-null    int64
#  1   HEIGHT       155 non-null    float64
#  2   HAND_LENGTH  155 non-null    float64
#  3   FOOT_LENGTH  155 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 5.0 KB

# %%
df['GENDER'] = df['GENDER'].map({1: 0, 2: 1})

# %%
df.head(108)
# Out:
#      GENDER  HEIGHT  HAND_LENGTH  FOOT_LENGTH
# 0         0  1760.2        208.6        269.6
# 1         0  1730.1        207.6        251.3
# 2         0  1659.6        173.2        193.6
# 3         0  1751.3        258.0        223.8
# 4         0  1780.6        212.3        282.1
# ..      ...     ...          ...          ...
# 103       1  1594.8        189.2        232.1
# 104       1  1619.5        193.3        239.9
# 105       1  1620.5        193.7        241.3
# 106       1  1571.7        188.5        232.2
# 107       1  1584.6        189.0        232.2
#
# [108 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(df['HEIGHT'], df['HAND_LENGTH'], c=df['GENDER'], cmap='viridis', alpha=0.7)

# %%
X = df[['HEIGHT', 'HAND_LENGTH', 'FOOT_LENGTH']]
y = df['GENDER']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
# array([[ 1.46762504e+00,  9.78333528e-01,  9.78904383e-01],
#        [-6.69975018e-01, -6.00719198e-01, -6.70748228e-01],
#        [-1.60470768e+00, -1.57070873e+00, -1.61727022e+00],
#        [-7.50094960e-01, -6.98470081e-01, -8.22191747e-01],
#        [ 1.12150689e+00,  9.63294930e-01,  1.00594787e+00],
#        [ 5.11527063e-01,  3.91828229e-01,  4.59669463e-01],
#        [ 1.12577995e+00,  8.20428255e-01,  9.46452200e-01],
#        [ 1.16851059e+00,  9.25698437e-01,  1.02758266e+00],
#        [ 6.67493884e-01,  5.72291398e-01,  6.32747769e-01],
#        [-1.14214854e+00, -9.76684133e-01, -9.30365688e-01],
#        [-3.99703746e-01, -4.35294627e-01, -5.73391681e-01],
#        [ 1.17812498e+00,  1.04600722e+00,  9.46452200e-01],
#        [-1.20624450e+00, -9.84203432e-01, -1.00608745e+00],
#        [-6.31517446e-01, -4.87929718e-01, -2.61247048e+00],
#        [-1.01182010e+00, -7.51105172e-01, -8.92504809e-01],
#        [-1.35259693e+00, -1.09699291e+00, -1.17375706e+00],
# ...

# %%
y_train
# Out:
# 30     0
# 90     1
# 117    1
# 137    1
# 18     0
#       ..
# 71     0
# 106    1
# 14     0
# 92     1
# 102    1
# Name: GENDER, Length: 139, dtype: int64

# %%
X_test
# Out:
# array([[-0.98618172, -1.54815083, -2.09323556],
#        [-1.01288837, -0.90149115, -1.00608745],
#        [ 0.92921903,  0.78283176,  0.75173911],
#        [ 1.00079284,  0.76779316,  0.78959998],
#        [-1.26072606, -0.90149115, -0.98445266],
#        [ 0.77218394,  0.69260018,  0.70306083],
#        [-0.67424808, -0.6157578 , -0.68156562],
#        [-0.95092895, -0.82629816, -0.9087309 ],
#        [-1.70085161, -1.11955081, -1.18457445],
#        [ 0.83200683,  0.63996509,  0.74633041],
#        [-0.2757849 ,  0.08353698,  0.59488689],
#        [-0.53964658, -0.6157578 , -0.81137435],
#        [ 0.92174117,  0.82794755,  0.87613914],
#        [ 0.06499192,  0.37678963,  0.7571478 ],
#        [ 0.16754544,  0.25648085,  0.32986073],
#        [ 1.8415181 ,  1.42949145,  1.73071328]])

# %%
y_test
# Out:
# 81     1
# 142    1
# 31     0
# 29     0
# 118    1
# 60     0
# 93     1
# 147    1
# 153    1
# 68     0
# 42     0
# 138    1
# 78     0
# 75     0
# 15     0
# 19     0
# Name: GENDER, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred= model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 1, 0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 0, 0, 0])

# %%
y_test
# Out:
# 81     1
# 142    1
# 31     0
# 29     0
# 118    1
# 60     0
# 93     1
# 147    1
# 153    1
# 68     0
# 42     0
# 138    1
# 78     0
# 75     0
# 15     0
# 19     0
# Name: GENDER, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9375

# %%
import matplotlib.pyplot as plt

plt.scatter(df['HEIGHT'], df['HAND_LENGTH'], c=df['GENDER'], cmap='viridis', alpha=0.7)
plt.xlabel('Height')
plt.ylabel('Hand Length')
plt.title('Gender classification based on Height and Hand Length')
plt.colorbar(label='Gender')  
plt.show()

# %%
import sklearn.metrics as f1
from sklearn.metrics import f1_score
f1_score_value = f1_score(y_test, y_pred)
print(f"F1 Score: {f1_score_value:.4f}")
plt.bar(['F1 Score'], [f1_score_value], color='blue')
plt.ylabel('Score')
plt.title('F1 Score of the Model')
plt.show()
# Out:
# F1 Score: 0.9333

# %%
import numpy as np
from sklearn.metrics import confusion_matrix,classification_report
import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()  
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.89      0.94         9
#            1       0.88      1.00      0.93         7
#
#     accuracy                           0.94        16
#    macro avg       0.94      0.94      0.94        16
# weighted avg       0.95      0.94      0.94        16
